# %%
from skimage import io

img1=io.imread('picture.jpg',as_grey=True)

print(type(img1))
print(img1.shape)

io.imshow(img1)
io.show()
# Out:
# <class 'numpy.ndarray'>
# (450, 600)
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
def article(person1,person2,person3,person4,place1,object1,object2,danger1):
    
    line1="空軍"+place1+"被丟包"+object1+"等二級"+danger1+"，結果官兵驗尿卻驗出8名涉及一級"+danger1+"，有媒體記者今天詢問國防部長"+person1+"現在給"+place1+"官兵打幾分，"+person1+"回說，「我想應該還是100分」，「100分部長應該帶出100分部隊」。他強調，吸"+danger1+"不是軍中獨有問題，但國防部每年控制到最低程度。"+person1+"並強調，「他應該相信我的部屬，彼此要有信心!」"
    
    line2="對於拾獲"+danger1+"是二級"+danger1+"，卻驗出是一級"+danger1+"，"+person1+"說，針由專業角度看這問題，就他所知，他們吃了感冒藥後會有一些不同反應，不是"+object1+"突然間升級到"+object2+"。"
    
    line3="另外，藍委"+person2+"則在質詢時爆料指出，些事件"+place1+"的聯隊長"+person3+"和黃姓士官督導長不合所以引發鬥爭，"+person1+"答詢表示，空軍司令"+person4+"告訴他，"+person3+"表現非常好，和黃姓士官長督導長合作也很好，並沒有鬥爭，而且「灑"+danger1+"也不需要灑那麼多，灑兩包就夠了。」"+"\n"
    
    line4="參考網址 : http://www.appledaily.com.tw/realtimenews/article/new/20170302.1067100/"
    
    print(" "+line1+line2)
    print(" "+line3)
    print(line4)
    
    from skimage import io,data
    img2 = data.astonaut()
    io.imshow(img2)
    io.show()
    
    print(type(img2))
    print(img2.shape)
    articl('牛昂星','蟹濕傅','零勝恩','嘟嘟360','老天鵝','米格魯','哈士奇','狗屎')
